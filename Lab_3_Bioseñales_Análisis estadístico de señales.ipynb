# %% [markdown]
# ## **LAB_3 Análisis estadístico de señales**
#
# - Luisa Llamas Baldovino
# - Camila Montiel Zapata

# %% [markdown]
# **1.Implementación de funciones**
#
#
# Implemente una función que permita calcular el valor cuadrático medio (RMS) de una señal.

# %%
import numpy as np

# %%
def RMS(N,X)
X_RMS = (1/N(np.sum(X**2)))**(1/2)
